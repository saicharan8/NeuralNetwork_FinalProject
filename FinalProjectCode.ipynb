# %%
# necessary imports 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('D://Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# checking for null values

df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
values = df.Exited.value_counts()
labels = ['Not Exited', 'Exited']

fig, ax = plt.subplots(figsize = (4, 3), dpi = 100)
explode = (0, 0.09)

patches, texts, autotexts = ax.pie(values, labels = labels, autopct = '%1.2f%%', shadow = True,
                                   startangle = 90, explode = explode)

plt.setp(texts, color = 'grey')
plt.setp(autotexts, size = 8, color = 'white')
autotexts[1].set_color('black')
plt.show()

# %%
# visualizing categorical variables
fig, ax = plt.subplots(3, 2, figsize=(18, 15))

sns.countplot(x='Geography', hue='Exited', data=df, ax=ax[0][0])
sns.countplot(x='Gender', hue='Exited', data=df, ax=ax[0][1])
sns.countplot(x='Tenure', hue='Exited', data=df, ax=ax[1][0])
sns.countplot(x='NumOfProducts', hue='Exited', data=df, ax=ax[1][1])
sns.countplot(x='HasCrCard', hue='Exited', data=df, ax=ax[2][0])
sns.countplot(x='IsActiveMember', hue='Exited', data=df, ax=ax[2][1])

plt.tight_layout()
plt.show()

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %%
# heatmap
plt.figure(figsize=(20, 12))

# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=[np.number]).columns
corr = df[numeric_columns].corr()

sns.heatmap(corr, linewidths=1, annot=True, fmt=".2f")
plt.show()

# %%
# dropping useless columns 

df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# creating features and label 
from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis=1)
y = to_categorical(df.Exited)

# Assuming you're using TensorFlow 2.x
from tensorflow.compat.v1.losses import sparse_softmax_cross_entropy
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 235/235 [==============================] - 2s 3ms/step - loss: 0.6073 - accuracy: 0.7279 - val_loss: 0.5416 - val_accuracy: 0.7904
# Epoch 2/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4475 - accuracy: 0.8204 - val_loss: 0.4223 - val_accuracy: 0.8184
# Epoch 3/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.3923 - accuracy: 0.8353 - val_loss: 0.3733 - val_accuracy: 0.8472
# Epoch 4/100
# 235/235 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8444 - val_loss: 0.3679 - val_accuracy: 0.8492
# Epoch 5/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3800 - accuracy: 0.8407 - val_loss: 0.3712 - val_accuracy: 0.8472
# Epoch 6/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.
validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 101)
sns.lineplot(x=epoch, y=train_loss, label = 'Training accuracy')
sns.lineplot(x=epoch, y=val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 1ms/step - loss: 0.3620 - accuracy: 0.8524
# Accuracy of model is 0.852400004863739

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dropout (Dropout)           (None, 10)                0
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dense_1 (Dense)             (None, 7)                 77
#
#  dropout_1 (Dropout)         (None, 7)                 0
#
#  batch_normalization_1 (Bat  (None, 7)                 28
#  chNormalization)
#
#  dense_2 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 237 (948.00 Byte)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________

# %%
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 3s 5ms/step - loss: 0.6398 - accuracy: 0.7181 - val_loss: 0.5722 - val_accuracy: 0.7904
# Epoch 2/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.5136 - accuracy: 0.7881 - val_loss: 0.4735 - val_accuracy: 0.7892
# Epoch 3/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4753 - accuracy: 0.7973 - val_loss: 0.4621 - val_accuracy: 0.7892
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4734 - accuracy: 0.7945 - val_loss: 0.4574 - val_accuracy: 0.7884
# Epoch 5/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4706 - accuracy: 0.7992 - val_loss: 0.4570 - val_accuracy: 0.7880
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4636 - accuracy: 0.7997 - val_loss: 0.4563 - val_accuracy: 0.7884
# Epoch 7/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4664 - accuracy: 0.7971 - val_loss: 0.4501 - val_accuracy: 0.7872
# Epoch 8/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4636 - accuracy: 0.7979 - val_loss: 0.4475 - val_accuracy: 0.7884
# Epoch 9/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4633 - accuracy: 0.7979 - val_loss: 0.4401 - val_accuracy: 0.7912
# Epoch 10/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4570 - accuracy: 0.8027 - val_loss: 0.4355 - val_accuracy: 0.7928
# Epoch 11/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4616 - accuracy: 0.7981 - val_loss: 0.4337 - val_accuracy: 0.8000
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4590 - accuracy: 0.8011 - val_loss: 0.4382 - val_accuracy: 0.7980
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4589 - accuracy: 0.7999 - val_loss: 0.4219 - val_accuracy: 0.8160
# Epoch 14/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4584 - accuracy: 0.8013 - val_loss: 0.4268 - val_accuracy: 0.8072
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4596 - accuracy: 0.8016 - val_loss: 0.4272 - val_accuracy: 0.8100
# Epoch 16/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4554 - accuracy: 0.8049 - val_loss: 0.4239 - val_accuracy: 0.8108
# Epoch 17/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4583 - accuracy: 0.8016 - val_loss: 0.4169 - val_accuracy: 0.8176
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4580 - accuracy: 0.8035 - val_loss: 0.4290 - val_accuracy: 0.8064
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4502 - accuracy: 0.8065 - val_loss: 0.4260 - val_accuracy: 0.8064
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4544 - accuracy: 0.8043 - val_loss: 0.4290 - val_accuracy: 0.8072
# Epoch 21/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4511 - accuracy: 0.8069 - val_loss: 0.4310 - val_accuracy: 0.8040
# Epoch 22/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.
100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4403 - accuracy: 0.8172 - val_loss: 0.4078 - val_accuracy: 0.8344
# Epoch 85/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4444 - accuracy: 0.8165 - val_loss: 0.4147 - val_accuracy: 0.8272
# Epoch 86/100
# 235/235 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.8151 - val_loss: 0.4115 - val_accuracy: 0.8352
# Epoch 87/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4443 - accuracy: 0.8167 - val_loss: 0.4103 - val_accuracy: 0.8336
# Epoch 88/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4414 - accuracy: 0.8205 - val_loss: 0.4071 - val_accuracy: 0.8368
# Epoch 89/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4475 - accuracy: 0.8149 - val_loss: 0.4114 - val_accuracy: 0.8316
# Epoch 90/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4485 - accuracy: 0.8129 - val_loss: 0.4085 - val_accuracy: 0.8364
# Epoch 91/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4470 - accuracy: 0.8133 - val_loss: 0.4118 - val_accuracy: 0.8292
# Epoch 92/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4481 - accuracy: 0.8124 - val_loss: 0.4064 - val_accuracy: 0.8348
# Epoch 93/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4488 - accuracy: 0.8096 - val_loss: 0.4085 - val_accuracy: 0.8284
# Epoch 94/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4477 - accuracy: 0.8117 - val_loss: 0.4125 - val_accuracy: 0.8232
# Epoch 95/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4478 - accuracy: 0.8139 - val_loss: 0.4109 - val_accuracy: 0.8272
# Epoch 96/100
# 235/235 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.8141 - val_loss: 0.4099 - val_accuracy: 0.8256
# Epoch 97/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4446 - accuracy: 0.8144 - val_loss: 0.4123 - val_accuracy: 0.8276
# Epoch 98/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4446 - accuracy: 0.8139 - val_loss: 0.4114 - val_accuracy: 0.8320
# Epoch 99/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4428 - accuracy: 0.8164 - val_loss: 0.4122 - val_accuracy: 0.8316
# Epoch 100/100
# 235/235 [==============================] - 1s 2ms/step - loss: 0.4484 - accuracy: 0.8127 - val_loss: 0.4100 - val_accuracy: 0.8300

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss'] 
epoch = range(1, 101)
sns.lineplot(x=epoch, y=train_loss, label = 'Training Loss')
sns.lineplot(x=epoch, y=val_loss, label = 'Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 101)
sns.lineplot(x=epoch, y=train_loss, label = 'Training accuracy')
sns.lineplot(x=epoch, y=val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 978us/step - loss: 0.4100 - accuracy: 0.8300
# Accuracy of model is 0.8299999833106995

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                110
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  batch_normalization_2 (Bat  (None, 10)                40
#  chNormalization)
#
#  dense_4 (Dense)             (None, 7)                 77
#
#  dropout_3 (Dropout)         (None, 7)                 0
#
#  batch_normalization_3 (Bat  (None, 7)                 28
#  chNormalization)
#
#  dense_5 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 237 (948.00 Byte)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________
